# %%
from matplotlib import pyplot as plt
# %matplotlib inline

from reader import Data, CTCBatchData

# %%
ds = Data("train")

# %%
ds.reset_state()

# %%
for dp in ds.get_data():
    cur_dp = dp
    break
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-4-dc66d7e27d89> in <module>()
# ----> 1 for dp in ds.get_data():
#       2     cur_dp = dp
#       3     break
#
# /home/jesse/tensorflow_workspace/tensorpack/examples/SeqRecog/reader.py in get_data(self)
#      75                 content = f.readlines()
#      76             label = self.mapper.encode_string(content[0])
# ---> 77             yield [feat, label]
#      78
#      79 class CTCBatchData(BatchData):
#
# UnboundLocalError: local variable 'feat' referenced before assignment

# %%
batch_ds = CTCBatchData(ds, 10)

# %%
for batch_dp in batch_ds.get_data():
    cur_batch_dp = batch_dp
    break

# %%
cur_batch_dp[0].shape

# %%
img_data = cur_batch_dp[0][0,:,:,0]

# %%
plt.imshow(img_data, cmap='gray')

# %%
from scipy import misc
from matplotlib import pyplot as plt
# %matplotlib inline
import numpy as np

# %%
img_path = "plate_recog/dadd0b9a-1c58-4863-9313-75424fea30f6.jpg"
img_1 = misc.imread(img_path, 'L')
img_2 = misc.imread(img_path, 'RGB')

# %%
np.sum(np.abs(img_1 - img_2))
# Out:
# 0.0

# %%
print(img_1.dtype)
print(img_2.dtype)
# Out:
# float32
# float32

# %%
plt.imshow(img_1)
